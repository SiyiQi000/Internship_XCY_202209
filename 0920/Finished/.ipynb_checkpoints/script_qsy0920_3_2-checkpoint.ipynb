# %% [markdown]
# ## 任务3，专利（3.7-3.8）!因无法调试各表，重复使用了变量名，需一个表一个表run

# %% [markdown]
# #### 表'3.技术产品-7研发实力-1企业重点实验室.xlsx'    ！区分‘相应级别’

# %% [markdown]
# 类型：备案，建设，考核，考评，立项，拟备案，拟筹建，拟建设，拟奖励，拟立项，拟批复，拟批复建设，拟批准，拟批准筹建，拟认定，拟认定建设，拟推荐，拟新建，拟资助，拟组建，培育建设，批复成立，批准建设，评估，评价，其他，取消，认定，申报，受理，通过初评，通过形式审查，通过验收，整改不通过，组建<p>
# 选择了：备案，建设，组建

# %%
import pandas as pd
import numpy as np
result=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_1基本信息\地址匹配.xlsx')

# %%
df2=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_3技术产品\3.技术产品-7研发实力-1企业重点实验室.xlsx')  #打开表,df2

#'建设','立项','培育建设','批复成立','批准建设','认定','通过验收','组建'

result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

#result2['认定归属年度']=pd.to_datetime(result2['认定归属年度']) #改为时间格式
#print(result2.info())

##b2021
result2_b2021 = result2[result2['认定归属年度']==2021] #只取2021年
result2_b2021 = result2_b2021[result2_b2021['类型'].isin(['备案','建设','组建'])]
result2_b2021_C = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_C_count = pd.DataFrame(result2_b2021_C.groupby(result2_b2021_C["所属市"])['公司编码'].count())
result2_b2021_P = result2_b2021[result2_b2021['相应级别'].isin(['省级'])]
result2_b2021_P_count = pd.DataFrame(result2_b2021_P.groupby(result2_b2021_P["所属市"])['公司编码'].count())
result2_b2021_M = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_M_count = pd.DataFrame(result2_b2021_M.groupby(result2_b2021_M["所属市"])['公司编码'].count())
#改名
result2_b2021_C_count=result2_b2021_C_count.rename(columns={'公司编码':'公司编码_2021_国家级_count'})
result2_b2021_P_count=result2_b2021_P_count.rename(columns={'公司编码':'公司编码_2021_省级_count'})
result2_b2021_M_count=result2_b2021_M_count.rename(columns={'公司编码':'公司编码_2021_市级_count'})


##b2020
result2_b2020 = result2[result2['认定归属年度']==2020] #只取2020年
result2_b2020 = result2_b2020[result2_b2020['类型'].isin(['备案','建设','组建'])]
result2_b2020_C = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_C_count = pd.DataFrame(result2_b2020_C.groupby(result2_b2020_C["所属市"])['公司编码'].count())
result2_b2020_P = result2_b2020[result2_b2020['相应级别'].isin(['省级'])]
result2_b2020_P_count = pd.DataFrame(result2_b2020_P.groupby(result2_b2020_P["所属市"])['公司编码'].count())
result2_b2020_M = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_M_count = pd.DataFrame(result2_b2020_M.groupby(result2_b2020_M["所属市"])['公司编码'].count())
#改名
result2_b2020_C_count=result2_b2020_C_count.rename(columns={'公司编码':'公司编码_2020_国家级_count'})
result2_b2020_P_count=result2_b2020_P_count.rename(columns={'公司编码':'公司编码_2020_省级_count'})
result2_b2020_M_count=result2_b2020_M_count.rename(columns={'公司编码':'公司编码_2020_市级_count'})


##b2019
result2_b2019 = result2[result2['认定归属年度']==2019] #只取2019年
result2_b2019 = result2_b2019[result2_b2019['类型'].isin(['备案','建设','组建'])]
result2_b2019_C = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_C_count = pd.DataFrame(result2_b2019_C.groupby(result2_b2019_C["所属市"])['公司编码'].count())
result2_b2019_P = result2_b2019[result2_b2019['相应级别'].isin(['省级'])]
result2_b2019_P_count = pd.DataFrame(result2_b2019_P.groupby(result2_b2019_P["所属市"])['公司编码'].count())
result2_b2019_M = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_M_count = pd.DataFrame(result2_b2019_M.groupby(result2_b2019_M["所属市"])['公司编码'].count())
#改名
result2_b2019_C_count=result2_b2019_C_count.rename(columns={'公司编码':'公司编码_2019_国家级_count'})
result2_b2019_P_count=result2_b2019_P_count.rename(columns={'公司编码':'公司编码_2019_省级_count'})
result2_b2019_M_count=result2_b2019_M_count.rename(columns={'公司编码':'公司编码_2019_市级_count'})


##合并输出
tbs = [result2_b2021_P_count,result2_b2021_M_count,result2_b2020_C_count,result2_b2020_P_count,result2_b2020_M_count,result2_b2019_C_count,result2_b2019_P_count,result2_b2019_M_count]
result2_final = result2_b2021_C_count
for tb in tbs:
    result2_final = result2_final.merge(tb, on=['所属市'], how='outer')

result2_final.to_excel("3.技术产品-7研发实力-1企业重点实验室_output.xlsx") #输出结果

# %% [markdown]
# #### 表'3.技术产品-7研发实力-2工业设计中心.xlsx'

# %% [markdown]
# 类型：初次认定，复评合格，复评优秀，拟认定，拟通过复核，拟推荐，培育，认定，通过复核<p>
# 选择了：培育，认定，通过复核

# %%
df2=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_3技术产品\3.技术产品-7研发实力-2工业设计中心.xlsx')  #打开表,df2

#'初次认定','复评合格','复评优秀','培育','认定','通过复核'

result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

#result2['认定归属年度']=pd.to_datetime(result2['认定归属年度']) #改为时间格式
#print(result2.info())


##b2021
result2_b2021 = result2[result2['认定归属年度']==2021] #只取2021年
result2_b2021 = result2_b2021[result2_b2021['类型'].isin(['培育','认定','通过复核'])]
result2_b2021_C = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_C_count = pd.DataFrame(result2_b2021_C.groupby(result2_b2021_C["所属市"])['公司编码'].count())
result2_b2021_P = result2_b2021[result2_b2021['相应级别'].isin(['省级'])]
result2_b2021_P_count = pd.DataFrame(result2_b2021_P.groupby(result2_b2021_P["所属市"])['公司编码'].count())
result2_b2021_M = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_M_count = pd.DataFrame(result2_b2021_M.groupby(result2_b2021_M["所属市"])['公司编码'].count())
#改名
result2_b2021_C_count=result2_b2021_C_count.rename(columns={'公司编码':'公司编码_2021_国家级_count'})
result2_b2021_P_count=result2_b2021_P_count.rename(columns={'公司编码':'公司编码_2021_省级_count'})
result2_b2021_M_count=result2_b2021_M_count.rename(columns={'公司编码':'公司编码_2021_市级_count'})


##b2020
result2_b2020 = result2[result2['认定归属年度']==2020] #只取2020年
result2_b2020 = result2_b2020[result2_b2020['类型'].isin(['培育','认定','通过复核'])]
result2_b2020_C = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_C_count = pd.DataFrame(result2_b2020_C.groupby(result2_b2020_C["所属市"])['公司编码'].count())
result2_b2020_P = result2_b2020[result2_b2020['相应级别'].isin(['省级'])]
result2_b2020_P_count = pd.DataFrame(result2_b2020_P.groupby(result2_b2020_P["所属市"])['公司编码'].count())
result2_b2020_M = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_M_count = pd.DataFrame(result2_b2020_M.groupby(result2_b2020_M["所属市"])['公司编码'].count())
#改名
result2_b2020_C_count=result2_b2020_C_count.rename(columns={'公司编码':'公司编码_2020_国家级_count'})
result2_b2020_P_count=result2_b2020_P_count.rename(columns={'公司编码':'公司编码_2020_省级_count'})
result2_b2020_M_count=result2_b2020_M_count.rename(columns={'公司编码':'公司编码_2020_市级_count'})


##b2019
result2_b2019 = result2[result2['认定归属年度']==2019] #只取2019年
result2_b2019 = result2_b2019[result2_b2019['类型'].isin(['培育','认定','通过复核'])]
result2_b2019_C = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_C_count = pd.DataFrame(result2_b2019_C.groupby(result2_b2019_C["所属市"])['公司编码'].count())
result2_b2019_P = result2_b2019[result2_b2019['相应级别'].isin(['省级'])]
result2_b2019_P_count = pd.DataFrame(result2_b2019_P.groupby(result2_b2019_P["所属市"])['公司编码'].count())
result2_b2019_M = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_M_count = pd.DataFrame(result2_b2019_M.groupby(result2_b2019_M["所属市"])['公司编码'].count())
#改名
result2_b2019_C_count=result2_b2019_C_count.rename(columns={'公司编码':'公司编码_2019_国家级_count'})
result2_b2019_P_count=result2_b2019_P_count.rename(columns={'公司编码':'公司编码_2019_省级_count'})
result2_b2019_M_count=result2_b2019_M_count.rename(columns={'公司编码':'公司编码_2019_市级_count'})


##合并输出
tbs = [result2_b2021_P_count,result2_b2021_M_count,result2_b2020_C_count,result2_b2020_P_count,result2_b2020_M_count,result2_b2019_C_count,result2_b2019_P_count,result2_b2019_M_count]
result2_final = result2_b2021_C_count
for tb in tbs:
    result2_final = result2_final.merge(tb, on=['所属市'], how='outer')

result2_final.to_excel("3.技术产品-7研发实力-2工业设计中心_output.xlsx") #输出结果

# %% [markdown]
# #### 表'3.技术产品-7研发实力-3企业技术中心.xlsx'

# %% [markdown]
# 类型：撤销，合格，拟认定，认定<p>
# 选择了：合格，认定

# %%
df2=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_3技术产品\3.技术产品-7研发实力-3企业技术中心.xlsx')  #打开表,df2

#'合格','认定'
result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

#result2['认定归属年度']=pd.to_datetime(result2['认定归属年度']) #改为时间格式
#print(result2.info())

##b2021
result2_b2021 = result2[result2['认定归属年度']==2021] #只取2021年
result2_b2021 = result2_b2021[result2_b2021['类型'].isin(['合格','认定'])]
result2_b2021_C = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_C_count = pd.DataFrame(result2_b2021_C.groupby(result2_b2021_C["所属市"])['公司编码'].count())
result2_b2021_P = result2_b2021[result2_b2021['相应级别'].isin(['省级'])]
result2_b2021_P_count = pd.DataFrame(result2_b2021_P.groupby(result2_b2021_P["所属市"])['公司编码'].count())
result2_b2021_M = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_M_count = pd.DataFrame(result2_b2021_M.groupby(result2_b2021_M["所属市"])['公司编码'].count())
#改名
result2_b2021_C_count=result2_b2021_C_count.rename(columns={'公司编码':'公司编码_2021_国家级_count'})
result2_b2021_P_count=result2_b2021_P_count.rename(columns={'公司编码':'公司编码_2021_省级_count'})
result2_b2021_M_count=result2_b2021_M_count.rename(columns={'公司编码':'公司编码_2021_市级_count'})


##b2020
result2_b2020 = result2[result2['认定归属年度']==2020] #只取2020年
result2_b2020 = result2_b2020[result2_b2020['类型'].isin(['合格','认定'])]
result2_b2020_C = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_C_count = pd.DataFrame(result2_b2020_C.groupby(result2_b2020_C["所属市"])['公司编码'].count())
result2_b2020_P = result2_b2020[result2_b2020['相应级别'].isin(['省级'])]
result2_b2020_P_count = pd.DataFrame(result2_b2020_P.groupby(result2_b2020_P["所属市"])['公司编码'].count())
result2_b2020_M = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_M_count = pd.DataFrame(result2_b2020_M.groupby(result2_b2020_M["所属市"])['公司编码'].count())
#改名
result2_b2020_C_count=result2_b2020_C_count.rename(columns={'公司编码':'公司编码_2020_国家级_count'})
result2_b2020_P_count=result2_b2020_P_count.rename(columns={'公司编码':'公司编码_2020_省级_count'})
result2_b2020_M_count=result2_b2020_M_count.rename(columns={'公司编码':'公司编码_2020_市级_count'})


##b2019
result2_b2019 = result2[result2['认定归属年度']==2019] #只取2019年
result2_b2019 = result2_b2019[result2_b2019['类型'].isin(['合格','认定'])]
result2_b2019_C = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_C_count = pd.DataFrame(result2_b2019_C.groupby(result2_b2019_C["所属市"])['公司编码'].count())
result2_b2019_P = result2_b2019[result2_b2019['相应级别'].isin(['省级'])]
result2_b2019_P_count = pd.DataFrame(result2_b2019_P.groupby(result2_b2019_P["所属市"])['公司编码'].count())
result2_b2019_M = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_M_count = pd.DataFrame(result2_b2019_M.groupby(result2_b2019_M["所属市"])['公司编码'].count())
#改名
result2_b2019_C_count=result2_b2019_C_count.rename(columns={'公司编码':'公司编码_2019_国家级_count'})
result2_b2019_P_count=result2_b2019_P_count.rename(columns={'公司编码':'公司编码_2019_省级_count'})
result2_b2019_M_count=result2_b2019_M_count.rename(columns={'公司编码':'公司编码_2019_市级_count'})


##合并输出
tbs = [result2_b2021_P_count,result2_b2021_M_count,result2_b2020_C_count,result2_b2020_P_count,result2_b2020_M_count,result2_b2019_C_count,result2_b2019_P_count,result2_b2019_M_count]
result2_final = result2_b2021_C_count
for tb in tbs:
    result2_final = result2_final.merge(tb, on=['所属市'], how='outer')

result2_final.to_excel("3.技术产品-7研发实力-3企业技术中心_output.xlsx") #输出结果

# %% [markdown]
# #### 表'3.技术产品-7研发实力-4院士专家工作站.xlsx'

# %% [markdown]
# 类型：保留，保留院士专家工作站，模范院士专家工作站，拟建设，拟建站，拟批建，拟确定，拟认定，批建，认定，示范院士专家工作站，续建<p>
# 选择了：保留，保留院士专家工作站，模范院士专家工作站，批建，认定，示范院士专家工作站，续建

# %%
df2=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_3技术产品\3.技术产品-7研发实力-4院士专家工作站.xlsx')  #打开表,df2

#'保留','保留院士专家工作站','模范院士专家工作站','批建','认定','示范院士专家工作站','续建'

result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

#result2['认定归属年度']=pd.to_datetime(result2['认定归属年度']) #改为时间格式
#print(result2.info())
#'保留','保留院士专家工作站','模范院士专家工作站','批建','认定','示范院士专家工作站','续建'
##b2021
result2_b2021 = result2[result2['认定归属年度']==2021] #只取2021年
result2_b2021 = result2_b2021[result2_b2021['类型'].isin(['保留','保留院士专家工作站','模范院士专家工作站','批建','认定','示范院士专家工作站','续建'])]
result2_b2021_C = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_C_count = pd.DataFrame(result2_b2021_C.groupby(result2_b2021_C["所属市"])['公司编码'].count())
result2_b2021_P = result2_b2021[result2_b2021['相应级别'].isin(['省级'])]
result2_b2021_P_count = pd.DataFrame(result2_b2021_P.groupby(result2_b2021_P["所属市"])['公司编码'].count())
result2_b2021_M = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_M_count = pd.DataFrame(result2_b2021_M.groupby(result2_b2021_M["所属市"])['公司编码'].count())
#改名
result2_b2021_C_count=result2_b2021_C_count.rename(columns={'公司编码':'公司编码_2021_国家级_count'})
result2_b2021_P_count=result2_b2021_P_count.rename(columns={'公司编码':'公司编码_2021_省级_count'})
result2_b2021_M_count=result2_b2021_M_count.rename(columns={'公司编码':'公司编码_2021_市级_count'})


##b2020
result2_b2020 = result2[result2['认定归属年度']==2020] #只取2020年
result2_b2020 = result2_b2020[result2_b2020['类型'].isin(['保留','保留院士专家工作站','模范院士专家工作站','批建','认定','示范院士专家工作站','续建'])]
result2_b2020_C = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_C_count = pd.DataFrame(result2_b2020_C.groupby(result2_b2020_C["所属市"])['公司编码'].count())
result2_b2020_P = result2_b2020[result2_b2020['相应级别'].isin(['省级'])]
result2_b2020_P_count = pd.DataFrame(result2_b2020_P.groupby(result2_b2020_P["所属市"])['公司编码'].count())
result2_b2020_M = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_M_count = pd.DataFrame(result2_b2020_M.groupby(result2_b2020_M["所属市"])['公司编码'].count())
#改名
result2_b2020_C_count=result2_b2020_C_count.rename(columns={'公司编码':'公司编码_2020_国家级_count'})
result2_b2020_P_count=result2_b2020_P_count.rename(columns={'公司编码':'公司编码_2020_省级_count'})
result2_b2020_M_count=result2_b2020_M_count.rename(columns={'公司编码':'公司编码_2020_市级_count'})


##b2019
result2_b2019 = result2[result2['认定归属年度']==2019] #只取2019年
result2_b2019 = result2_b2019[result2_b2019['类型'].isin(['保留','保留院士专家工作站','模范院士专家工作站','批建','认定','示范院士专家工作站','续建'])]
result2_b2019_C = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_C_count = pd.DataFrame(result2_b2019_C.groupby(result2_b2019_C["所属市"])['公司编码'].count())
result2_b2019_P = result2_b2019[result2_b2019['相应级别'].isin(['省级'])]
result2_b2019_P_count = pd.DataFrame(result2_b2019_P.groupby(result2_b2019_P["所属市"])['公司编码'].count())
result2_b2019_M = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_M_count = pd.DataFrame(result2_b2019_M.groupby(result2_b2019_M["所属市"])['公司编码'].count())
#改名
result2_b2019_C_count=result2_b2019_C_count.rename(columns={'公司编码':'公司编码_2019_国家级_count'})
result2_b2019_P_count=result2_b2019_P_count.rename(columns={'公司编码':'公司编码_2019_省级_count'})
result2_b2019_M_count=result2_b2019_M_count.rename(columns={'公司编码':'公司编码_2019_市级_count'})


##合并输出
tbs = [result2_b2021_P_count,result2_b2021_M_count,result2_b2020_C_count,result2_b2020_P_count,result2_b2020_M_count,result2_b2019_C_count,result2_b2019_P_count,result2_b2019_M_count]
result2_final = result2_b2021_C_count
for tb in tbs:
    result2_final = result2_final.merge(tb, on=['所属市'], how='outer')

result2_final.to_excel("3.技术产品-7研发实力-4院士专家工作站_output.xlsx") #输出结果

# %% [markdown]
# #### 表'3.技术产品-7研发实力-5工程研究中心实验室.xlsx'

# %% [markdown]
# 类型：拟建设，拟奖励，拟命名，拟批复，拟批建，拟确定，拟认定，拟推荐，拟新建，拟验收，拟组建，批复，批建，认定，通过验收<p>
# 选择了：批复，批建，认定，通过验收

# %%
df2=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_3技术产品\3.技术产品-7研发实力-5工程研究中心实验室.xlsx')  #打开表,df2

#'批复','批建','认定','通过验收'
##b2021
result2_b2021 = result2[result2['认定归属年度']==2021] #只取2021年
result2_b2021 = result2_b2021[result2_b2021['类型'].isin(['批复','批建','认定','通过验收'])]
result2_b2021_C = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_C_count = pd.DataFrame(result2_b2021_C.groupby(result2_b2021_C["所属市"])['公司编码'].count())
result2_b2021_P = result2_b2021[result2_b2021['相应级别'].isin(['省级'])]
result2_b2021_P_count = pd.DataFrame(result2_b2021_P.groupby(result2_b2021_P["所属市"])['公司编码'].count())
result2_b2021_M = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_M_count = pd.DataFrame(result2_b2021_M.groupby(result2_b2021_M["所属市"])['公司编码'].count())
#改名
result2_b2021_C_count=result2_b2021_C_count.rename(columns={'公司编码':'公司编码_2021_国家级_count'})
result2_b2021_P_count=result2_b2021_P_count.rename(columns={'公司编码':'公司编码_2021_省级_count'})
result2_b2021_M_count=result2_b2021_M_count.rename(columns={'公司编码':'公司编码_2021_市级_count'})


##b2020
result2_b2020 = result2[result2['认定归属年度']==2020] #只取2020年
result2_b2020 = result2_b2020[result2_b2020['类型'].isin(['批复','批建','认定','通过验收'])]
result2_b2020_C = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_C_count = pd.DataFrame(result2_b2020_C.groupby(result2_b2020_C["所属市"])['公司编码'].count())
result2_b2020_P = result2_b2020[result2_b2020['相应级别'].isin(['省级'])]
result2_b2020_P_count = pd.DataFrame(result2_b2020_P.groupby(result2_b2020_P["所属市"])['公司编码'].count())
result2_b2020_M = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_M_count = pd.DataFrame(result2_b2020_M.groupby(result2_b2020_M["所属市"])['公司编码'].count())
#改名
result2_b2020_C_count=result2_b2020_C_count.rename(columns={'公司编码':'公司编码_2020_国家级_count'})
result2_b2020_P_count=result2_b2020_P_count.rename(columns={'公司编码':'公司编码_2020_省级_count'})
result2_b2020_M_count=result2_b2020_M_count.rename(columns={'公司编码':'公司编码_2020_市级_count'})


##b2019
result2_b2019 = result2[result2['认定归属年度']==2019] #只取2019年
result2_b2019 = result2_b2019[result2_b2019['类型'].isin(['批复','批建','认定','通过验收'])]
result2_b2019_C = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_C_count = pd.DataFrame(result2_b2019_C.groupby(result2_b2019_C["所属市"])['公司编码'].count())
result2_b2019_P = result2_b2019[result2_b2019['相应级别'].isin(['省级'])]
result2_b2019_P_count = pd.DataFrame(result2_b2019_P.groupby(result2_b2019_P["所属市"])['公司编码'].count())
result2_b2019_M = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_M_count = pd.DataFrame(result2_b2019_M.groupby(result2_b2019_M["所属市"])['公司编码'].count())
#改名
result2_b2019_C_count=result2_b2019_C_count.rename(columns={'公司编码':'公司编码_2019_国家级_count'})
result2_b2019_P_count=result2_b2019_P_count.rename(columns={'公司编码':'公司编码_2019_省级_count'})
result2_b2019_M_count=result2_b2019_M_count.rename(columns={'公司编码':'公司编码_2019_市级_count'})


##合并输出
tbs = [result2_b2021_P_count,result2_b2021_M_count,result2_b2020_C_count,result2_b2020_P_count,result2_b2020_M_count,result2_b2019_C_count,result2_b2019_P_count,result2_b2019_M_count]
result2_final = result2_b2021_C_count
for tb in tbs:
    result2_final = result2_final.merge(tb, on=['所属市'], how='outer')

result2_final.to_excel("3.技术产品-7研发实力-5工程研究中心实验室_output.xlsx") #输出结果

# %% [markdown]
# #### 表'3.技术产品-7研发实力-6新型研发机构.xlsx'   ！区分'相应级别'

# %% [markdown]
# 类型：备案，备案培育，拟备案，拟拨付，拟立项，拟命名，拟培育，拟认定，拟支持，培育，评估，认定，试点培育，推荐备案<p>
# 选择了：备案，备案培育，认定，试点培育

# %%
df2=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_3技术产品\3.技术产品-7研发实力-6新型研发机构.xlsx')  #打开表,df2

#'培育','认定','试点培育','拟立项','拟培育','拟认定','拟支持'

result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

#result2['认定归属年度']=pd.to_datetime(result2['认定归属年度']) #改为时间格式
#print(result2.info())
#'备案','备案培育','认定','试点培育'

##b2021
result2_b2021 = result2[result2['认定归属年度']==2021] #只取2021年
result2_b2021 = result2_b2021[result2_b2021['类型'].isin(['备案','备案培育','认定','试点培育'])]
result2_b2021_C = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_C_count = pd.DataFrame(result2_b2021_C.groupby(result2_b2021_C["所属市"])['公司编码'].count())
result2_b2021_P = result2_b2021[result2_b2021['相应级别'].isin(['省级'])]
result2_b2021_P_count = pd.DataFrame(result2_b2021_P.groupby(result2_b2021_P["所属市"])['公司编码'].count())
result2_b2021_M = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_M_count = pd.DataFrame(result2_b2021_M.groupby(result2_b2021_M["所属市"])['公司编码'].count())
#改名
result2_b2021_C_count=result2_b2021_C_count.rename(columns={'公司编码':'公司编码_2021_国家级_count'})
result2_b2021_P_count=result2_b2021_P_count.rename(columns={'公司编码':'公司编码_2021_省级_count'})
result2_b2021_M_count=result2_b2021_M_count.rename(columns={'公司编码':'公司编码_2021_市级_count'})


##b2020
result2_b2020 = result2[result2['认定归属年度']==2020] #只取2020年
result2_b2020 = result2_b2020[result2_b2020['类型'].isin(['备案','备案培育','认定','试点培育'])]
result2_b2020_C = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_C_count = pd.DataFrame(result2_b2020_C.groupby(result2_b2020_C["所属市"])['公司编码'].count())
result2_b2020_P = result2_b2020[result2_b2020['相应级别'].isin(['省级'])]
result2_b2020_P_count = pd.DataFrame(result2_b2020_P.groupby(result2_b2020_P["所属市"])['公司编码'].count())
result2_b2020_M = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_M_count = pd.DataFrame(result2_b2020_M.groupby(result2_b2020_M["所属市"])['公司编码'].count())
#改名
result2_b2020_C_count=result2_b2020_C_count.rename(columns={'公司编码':'公司编码_2020_国家级_count'})
result2_b2020_P_count=result2_b2020_P_count.rename(columns={'公司编码':'公司编码_2020_省级_count'})
result2_b2020_M_count=result2_b2020_M_count.rename(columns={'公司编码':'公司编码_2020_市级_count'})


##b2019
result2_b2019 = result2[result2['认定归属年度']==2019] #只取2019年
result2_b2019 = result2_b2019[result2_b2019['类型'].isin(['备案','备案培育','认定','试点培育'])]
result2_b2019_C = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_C_count = pd.DataFrame(result2_b2019_C.groupby(result2_b2019_C["所属市"])['公司编码'].count())
result2_b2019_P = result2_b2019[result2_b2019['相应级别'].isin(['省级'])]
result2_b2019_P_count = pd.DataFrame(result2_b2019_P.groupby(result2_b2019_P["所属市"])['公司编码'].count())
result2_b2019_M = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_M_count = pd.DataFrame(result2_b2019_M.groupby(result2_b2019_M["所属市"])['公司编码'].count())
#改名
result2_b2019_C_count=result2_b2019_C_count.rename(columns={'公司编码':'公司编码_2019_国家级_count'})
result2_b2019_P_count=result2_b2019_P_count.rename(columns={'公司编码':'公司编码_2019_省级_count'})
result2_b2019_M_count=result2_b2019_M_count.rename(columns={'公司编码':'公司编码_2019_市级_count'})


##合并输出
tbs = [result2_b2021_P_count,result2_b2021_M_count,result2_b2020_C_count,result2_b2020_P_count,result2_b2020_M_count,result2_b2019_C_count,result2_b2019_P_count,result2_b2019_M_count]
result2_final = result2_b2021_C_count
for tb in tbs:
    result2_final = result2_final.merge(tb, on=['所属市'], how='outer')

result2_final.to_excel("3.技术产品-7研发实力-6新型研发机构_output.xlsx") #输出结果

# %% [markdown]
# #### 表'3.技术产品-7研发实力-7高新技术企业研发中心.xlsx'   ！区分'相应级别'

# %%
df2=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_3技术产品\3.技术产品-7研发实力-7高新技术企业研发中心.xlsx')  #打开表,df2

result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

#result2['认定归属年度']=pd.to_datetime(result2['认定归属年度']) #改为时间格式
#print(result2.info())

##b2021
result2_b2021 = result2[result2['认定归属年度']==2021] #只取2021年
result2_b2021_C = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_C_count = pd.DataFrame(result2_b2021_C.groupby(result2_b2021_C["所属市"])['公司编码'].count())
result2_b2021_P = result2_b2021[result2_b2021['相应级别'].isin(['省级'])]
result2_b2021_P_count = pd.DataFrame(result2_b2021_P.groupby(result2_b2021_P["所属市"])['公司编码'].count())
result2_b2021_M = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_M_count = pd.DataFrame(result2_b2021_M.groupby(result2_b2021_M["所属市"])['公司编码'].count())
#改名
result2_b2021_C_count=result2_b2021_C_count.rename(columns={'公司编码':'公司编码_2021_国家级_count'})
result2_b2021_P_count=result2_b2021_P_count.rename(columns={'公司编码':'公司编码_2021_省级_count'})
result2_b2021_M_count=result2_b2021_M_count.rename(columns={'公司编码':'公司编码_2021_市级_count'})


##b2020
result2_b2020 = result2[result2['认定归属年度']==2020] #只取2020年
result2_b2020_C = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_C_count = pd.DataFrame(result2_b2020_C.groupby(result2_b2020_C["所属市"])['公司编码'].count())
result2_b2020_P = result2_b2020[result2_b2020['相应级别'].isin(['省级'])]
result2_b2020_P_count = pd.DataFrame(result2_b2020_P.groupby(result2_b2020_P["所属市"])['公司编码'].count())
result2_b2020_M = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_M_count = pd.DataFrame(result2_b2020_M.groupby(result2_b2020_M["所属市"])['公司编码'].count())
#改名
result2_b2020_C_count=result2_b2020_C_count.rename(columns={'公司编码':'公司编码_2020_国家级_count'})
result2_b2020_P_count=result2_b2020_P_count.rename(columns={'公司编码':'公司编码_2020_省级_count'})
result2_b2020_M_count=result2_b2020_M_count.rename(columns={'公司编码':'公司编码_2020_市级_count'})


##b2019
result2_b2019 = result2[result2['认定归属年度']==2019] #只取2019年
result2_b2019_C = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_C_count = pd.DataFrame(result2_b2019_C.groupby(result2_b2019_C["所属市"])['公司编码'].count())
result2_b2019_P = result2_b2019[result2_b2019['相应级别'].isin(['省级'])]
result2_b2019_P_count = pd.DataFrame(result2_b2019_P.groupby(result2_b2019_P["所属市"])['公司编码'].count())
result2_b2019_M = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_M_count = pd.DataFrame(result2_b2019_M.groupby(result2_b2019_M["所属市"])['公司编码'].count())
#改名
result2_b2019_C_count=result2_b2019_C_count.rename(columns={'公司编码':'公司编码_2019_国家级_count'})
result2_b2019_P_count=result2_b2019_P_count.rename(columns={'公司编码':'公司编码_2019_省级_count'})
result2_b2019_M_count=result2_b2019_M_count.rename(columns={'公司编码':'公司编码_2019_市级_count'})


##合并输出
tbs = [result2_b2021_P_count,result2_b2021_M_count,result2_b2020_C_count,result2_b2020_P_count,result2_b2020_M_count,result2_b2019_C_count,result2_b2019_P_count,result2_b2019_M_count]
result2_final = result2_b2021_C_count
for tb in tbs:
    result2_final = result2_final.merge(tb, on=['所属市'], how='outer')

result2_final.to_excel("3.技术产品-7研发实力-7高新技术企业研发中心_output.xlsx") #输出结果

# %% [markdown]
# #### 表'3.技术产品-8科创资质-1高新技术企业.xlsx'

# %%
df2=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_3技术产品\3.技术产品-8科创资质-1高新技术企业.xlsx')  #打开表,df2

result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

#result2['认定归属年度']=pd.to_datetime(result2['认定归属年度']) #改为时间格式
#print(result2.info())

##b2021
result2_b2021 = result2[result2['年度']==2021] #只取2021年之前
result2_b2021_count = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['公司编码'].count())
#改名
result2_b2021_count=result2_b2021_count.rename(columns={'公司编码':'公司编码_2021_count'})
result2_b2021_final=result2_b2021_count

##b2020
result2_b2020 = result2[result2['年度']==2020] #只取2020年之前
result2_b2020_count = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['公司编码'].count())
#改名
result2_b2020_count=result2_b2020_count.rename(columns={'公司编码':'公司编码_2020_count'})
result2_b2020_final=result2_b2020_count

##b2019
result2_b2019 = result2[result2['年度']==2019] #只取2019年之前
result2_b2019_count = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['公司编码'].count())
#改名
result2_b2019_count=result2_b2019_count.rename(columns={'公司编码':'公司编码_2019_count'})
result2_b2019_final=result2_b2019_count

##合并年份4个表并输出
tbs = [result2_b2020_final,result2_b2019_final]
result2_final = result2_b2021_final
for tb in tbs:
    result2_final = result2_final.merge(tb, on=['所属市'], how='outer')

result2_final.to_excel("3.技术产品-8科创资质-1高新技术企业_output.xlsx") #输出结果

# %% [markdown]
# #### 表'3.技术产品-8科创资质-2科技型中小企业.xlsx'

# %%
import pandas as pd
import numpy as np
result=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_1基本信息\地址匹配.xlsx')

# %%
df2=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_3技术产品\3.技术产品-8科创资质-2科技型中小企业_new.xlsx')  #打开表,df2

result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result
##b2021
result2_b2021 = result2[result2['年份']==2021] #只取2021年之前
result2_b2021_count = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['公司编码'].count())
#改名
result2_b2021_count=result2_b2021_count.rename(columns={'公司编码':'公司编码_2021_count'})
result2_b2021_final=result2_b2021_count

##b2020
result2_b2020 = result2[result2['年份']==2020] #只取2020年之前
result2_b2020_count = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['公司编码'].count())
#改名
result2_b2020_count=result2_b2020_count.rename(columns={'公司编码':'公司编码_2020_count'})
result2_b2020_final=result2_b2020_count

##b2019
result2_b2019 = result2[result2['年份']==2019] #只取2019年之前
result2_b2019_count = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['公司编码'].count())
#改名
result2_b2019_count=result2_b2019_count.rename(columns={'公司编码':'公司编码_2019_count'})
result2_b2019_final=result2_b2019_count

##合并年份4个表并输出
tbs = [result2_b2020_final,result2_b2019_final]
result2_final = result2_b2021_final
for tb in tbs:
    result2_final = result2_final.merge(tb, on=['所属市'], how='outer')

result2_final.to_excel("3.技术产品-8科创资质-2科技型中小企业_output.xlsx") #输出结果

# %% [markdown]
# #### 表'3.技术产品-8科创资质-3专精特新小巨人企业.xlsx'   ！区分‘相应级别’

# %%
df2=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_3技术产品\3.技术产品-8科创资质-3专精特新小巨人企业.xlsx')  #打开表,df2

result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

#result2['认定归属年度']=pd.to_datetime(result2['认定归属年度']) #改为时间格式
#print(result2.info())

##b2021
result2_b2021 = result2[result2['认定归属年度']==2021] #只取2021年
result2_b2021_C = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_C_count = pd.DataFrame(result2_b2021_C.groupby(result2_b2021_C["所属市"])['公司编码'].count())
result2_b2021_P = result2_b2021[result2_b2021['相应级别'].isin(['省级'])]
result2_b2021_P_count = pd.DataFrame(result2_b2021_P.groupby(result2_b2021_P["所属市"])['公司编码'].count())
result2_b2021_M = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_M_count = pd.DataFrame(result2_b2021_M.groupby(result2_b2021_M["所属市"])['公司编码'].count())
#改名
result2_b2021_C_count=result2_b2021_C_count.rename(columns={'公司编码':'公司编码_2021_国家级_count'})
result2_b2021_P_count=result2_b2021_P_count.rename(columns={'公司编码':'公司编码_2021_省级_count'})
result2_b2021_M_count=result2_b2021_M_count.rename(columns={'公司编码':'公司编码_2021_市级_count'})


##b2020
result2_b2020 = result2[result2['认定归属年度']==2020] #只取2020年
result2_b2020_C = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_C_count = pd.DataFrame(result2_b2020_C.groupby(result2_b2020_C["所属市"])['公司编码'].count())
result2_b2020_P = result2_b2020[result2_b2020['相应级别'].isin(['省级'])]
result2_b2020_P_count = pd.DataFrame(result2_b2020_P.groupby(result2_b2020_P["所属市"])['公司编码'].count())
result2_b2020_M = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_M_count = pd.DataFrame(result2_b2020_M.groupby(result2_b2020_M["所属市"])['公司编码'].count())
#改名
result2_b2020_C_count=result2_b2020_C_count.rename(columns={'公司编码':'公司编码_2020_国家级_count'})
result2_b2020_P_count=result2_b2020_P_count.rename(columns={'公司编码':'公司编码_2020_省级_count'})
result2_b2020_M_count=result2_b2020_M_count.rename(columns={'公司编码':'公司编码_2020_市级_count'})


##b2019
result2_b2019 = result2[result2['认定归属年度']==2019] #只取2019年
result2_b2019_C = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_C_count = pd.DataFrame(result2_b2019_C.groupby(result2_b2019_C["所属市"])['公司编码'].count())
result2_b2019_P = result2_b2019[result2_b2019['相应级别'].isin(['省级'])]
result2_b2019_P_count = pd.DataFrame(result2_b2019_P.groupby(result2_b2019_P["所属市"])['公司编码'].count())
result2_b2019_M = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_M_count = pd.DataFrame(result2_b2019_M.groupby(result2_b2019_M["所属市"])['公司编码'].count())
#改名
result2_b2019_C_count=result2_b2019_C_count.rename(columns={'公司编码':'公司编码_2019_国家级_count'})
result2_b2019_P_count=result2_b2019_P_count.rename(columns={'公司编码':'公司编码_2019_省级_count'})
result2_b2019_M_count=result2_b2019_M_count.rename(columns={'公司编码':'公司编码_2019_市级_count'})


##合并输出
tbs = [result2_b2021_P_count,result2_b2021_M_count,result2_b2020_C_count,result2_b2020_P_count,result2_b2020_M_count,result2_b2019_C_count,result2_b2019_P_count,result2_b2019_M_count]
result2_final = result2_b2021_C_count
for tb in tbs:
    result2_final = result2_final.merge(tb, on=['所属市'], how='outer')


result2_final.to_excel("3.技术产品-8科创资质-3专精特新小巨人企业_output.xlsx") #输出结果

# %% [markdown]
# #### 表'3.技术产品-8科创资质-4技术创新示范企业.xlsx'

# %% [markdown]
# 类型：复检合格，拟认定，确认，认定<p>
# 选择了：确认，认定

# %%
df2=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_3技术产品\3.技术产品-8科创资质-4技术创新示范企业.xlsx')  #打开表,df2

result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

#result2['认定归属年度']=pd.to_datetime(result2['认定归属年度']) #改为时间格式
#print(result2.info())

##b2021
result2_b2021 = result2[result2['认定归属年度']==2021] #只取2021年
result2_b2021 = result2_b2021[result2_b2021['类型'].isin(['确认','认定'])]
result2_b2021_C = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_C_count = pd.DataFrame(result2_b2021_C.groupby(result2_b2021_C["所属市"])['公司编码'].count())
result2_b2021_P = result2_b2021[result2_b2021['相应级别'].isin(['省级'])]
result2_b2021_P_count = pd.DataFrame(result2_b2021_P.groupby(result2_b2021_P["所属市"])['公司编码'].count())
result2_b2021_M = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_M_count = pd.DataFrame(result2_b2021_M.groupby(result2_b2021_M["所属市"])['公司编码'].count())
#改名
result2_b2021_C_count=result2_b2021_C_count.rename(columns={'公司编码':'公司编码_2021_国家级_count'})
result2_b2021_P_count=result2_b2021_P_count.rename(columns={'公司编码':'公司编码_2021_省级_count'})
result2_b2021_M_count=result2_b2021_M_count.rename(columns={'公司编码':'公司编码_2021_市级_count'})


##b2020
result2_b2020 = result2[result2['认定归属年度']==2020] #只取2020年
result2_b2020 = result2_b2020[result2_b2020['类型'].isin(['确认','认定'])]
result2_b2020_C = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_C_count = pd.DataFrame(result2_b2020_C.groupby(result2_b2020_C["所属市"])['公司编码'].count())
result2_b2020_P = result2_b2020[result2_b2020['相应级别'].isin(['省级'])]
result2_b2020_P_count = pd.DataFrame(result2_b2020_P.groupby(result2_b2020_P["所属市"])['公司编码'].count())
result2_b2020_M = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_M_count = pd.DataFrame(result2_b2020_M.groupby(result2_b2020_M["所属市"])['公司编码'].count())
#改名
result2_b2020_C_count=result2_b2020_C_count.rename(columns={'公司编码':'公司编码_2020_国家级_count'})
result2_b2020_P_count=result2_b2020_P_count.rename(columns={'公司编码':'公司编码_2020_省级_count'})
result2_b2020_M_count=result2_b2020_M_count.rename(columns={'公司编码':'公司编码_2020_市级_count'})


##b2019
result2_b2019 = result2[result2['认定归属年度']==2019] #只取2019年
result2_b2019 = result2_b2019[result2_b2019['类型'].isin(['确认','认定'])]
result2_b2019_C = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_C_count = pd.DataFrame(result2_b2019_C.groupby(result2_b2019_C["所属市"])['公司编码'].count())
result2_b2019_P = result2_b2019[result2_b2019['相应级别'].isin(['省级'])]
result2_b2019_P_count = pd.DataFrame(result2_b2019_P.groupby(result2_b2019_P["所属市"])['公司编码'].count())
result2_b2019_M = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_M_count = pd.DataFrame(result2_b2019_M.groupby(result2_b2019_M["所属市"])['公司编码'].count())
#改名
result2_b2019_C_count=result2_b2019_C_count.rename(columns={'公司编码':'公司编码_2019_国家级_count'})
result2_b2019_P_count=result2_b2019_P_count.rename(columns={'公司编码':'公司编码_2019_省级_count'})
result2_b2019_M_count=result2_b2019_M_count.rename(columns={'公司编码':'公司编码_2019_市级_count'})


##合并输出
tbs = [result2_b2021_P_count,result2_b2021_M_count,result2_b2020_C_count,result2_b2020_P_count,result2_b2020_M_count,result2_b2019_C_count,result2_b2019_P_count,result2_b2019_M_count]
result2_final = result2_b2021_C_count
for tb in tbs:
    result2_final = result2_final.merge(tb, on=['所属市'], how='outer')
result2_final.to_excel("3.技术产品-8科创资质-4技术创新示范企业_output.xlsx") #输出结果

# %% [markdown]
# #### 表'3.技术产品-8科创资质-5服务型制造示范企业.xlsx'   ！区分‘相应级别’

# %% [markdown]
# 类型：拟遴选，拟认定，培育，认定<p>
# 选择了：培育，认定

# %%
df2=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_3技术产品\3.技术产品-8科创资质-5服务型制造示范企业.xlsx')  #打开表,df2



result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

#result2['认定归属年度']=pd.to_datetime(result2['认定归属年度']) #改为时间格式
#print(result2.info())
#'培育','认定'
##b2021
result2_b2021 = result2[result2['认定归属年度']==2021] #只取2021年
result2_b2021 = result2_b2021[result2_b2021['类型'].isin(['培育','认定'])]
result2_b2021_C = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_C_count = pd.DataFrame(result2_b2021_C.groupby(result2_b2021_C["所属市"])['公司编码'].count())
result2_b2021_P = result2_b2021[result2_b2021['相应级别'].isin(['省级'])]
result2_b2021_P_count = pd.DataFrame(result2_b2021_P.groupby(result2_b2021_P["所属市"])['公司编码'].count())
result2_b2021_M = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_M_count = pd.DataFrame(result2_b2021_M.groupby(result2_b2021_M["所属市"])['公司编码'].count())
#改名
result2_b2021_C_count=result2_b2021_C_count.rename(columns={'公司编码':'公司编码_2021_国家级_count'})
result2_b2021_P_count=result2_b2021_P_count.rename(columns={'公司编码':'公司编码_2021_省级_count'})
result2_b2021_M_count=result2_b2021_M_count.rename(columns={'公司编码':'公司编码_2021_市级_count'})


##b2020
result2_b2020 = result2[result2['认定归属年度']==2020] #只取2020年
result2_b2020 = result2_b2020[result2_b2020['类型'].isin(['培育','认定'])]
result2_b2020_C = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_C_count = pd.DataFrame(result2_b2020_C.groupby(result2_b2020_C["所属市"])['公司编码'].count())
result2_b2020_P = result2_b2020[result2_b2020['相应级别'].isin(['省级'])]
result2_b2020_P_count = pd.DataFrame(result2_b2020_P.groupby(result2_b2020_P["所属市"])['公司编码'].count())
result2_b2020_M = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_M_count = pd.DataFrame(result2_b2020_M.groupby(result2_b2020_M["所属市"])['公司编码'].count())
#改名
result2_b2020_C_count=result2_b2020_C_count.rename(columns={'公司编码':'公司编码_2020_国家级_count'})
result2_b2020_P_count=result2_b2020_P_count.rename(columns={'公司编码':'公司编码_2020_省级_count'})
result2_b2020_M_count=result2_b2020_M_count.rename(columns={'公司编码':'公司编码_2020_市级_count'})


##b2019
result2_b2019 = result2[result2['认定归属年度']==2019] #只取2019年
result2_b2019 = result2_b2019[result2_b2019['类型'].isin(['培育','认定'])]
result2_b2019_C = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_C_count = pd.DataFrame(result2_b2019_C.groupby(result2_b2019_C["所属市"])['公司编码'].count())
result2_b2019_P = result2_b2019[result2_b2019['相应级别'].isin(['省级'])]
result2_b2019_P_count = pd.DataFrame(result2_b2019_P.groupby(result2_b2019_P["所属市"])['公司编码'].count())
result2_b2019_M = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_M_count = pd.DataFrame(result2_b2019_M.groupby(result2_b2019_M["所属市"])['公司编码'].count())
#改名
result2_b2019_C_count=result2_b2019_C_count.rename(columns={'公司编码':'公司编码_2019_国家级_count'})
result2_b2019_P_count=result2_b2019_P_count.rename(columns={'公司编码':'公司编码_2019_省级_count'})
result2_b2019_M_count=result2_b2019_M_count.rename(columns={'公司编码':'公司编码_2019_市级_count'})


##合并输出
tbs = [result2_b2021_P_count,result2_b2021_M_count,result2_b2020_C_count,result2_b2020_P_count,result2_b2020_M_count,result2_b2019_C_count,result2_b2019_P_count,result2_b2019_M_count]
result2_final = result2_b2021_C_count
for tb in tbs:
    result2_final = result2_final.merge(tb, on=['所属市'], how='outer')

result2_final.to_excel("3.技术产品-8科创资质-5服务型制造示范企业_output.xlsx") #输出结果

# %% [markdown]
# #### 表'3.技术产品-8科创资质-6制造业单项冠军.xlsx'   ！区分‘相应级别’

# %%
df2=pd.read_excel(r'E:\思懿-已更新数据文件夹2\qsy_3技术产品\3.技术产品-8科创资质-6制造业单项冠军.xlsx')  #打开表,df2

result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

#result2['认定归属年度']=pd.to_datetime(result2['认定归属年度']) #改为时间格式
#print(result2.info())

##b2021
result2_b2021 = result2[result2['认定归属年度']==2021] #只取2021年
result2_b2021_C = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_C_count = pd.DataFrame(result2_b2021_C.groupby(result2_b2021_C["所属市"])['公司编码'].count())
result2_b2021_P = result2_b2021[result2_b2021['相应级别'].isin(['省级'])]
result2_b2021_P_count = pd.DataFrame(result2_b2021_P.groupby(result2_b2021_P["所属市"])['公司编码'].count())
result2_b2021_M = result2_b2021[result2_b2021['相应级别'].isin(['国家级'])]
result2_b2021_M_count = pd.DataFrame(result2_b2021_M.groupby(result2_b2021_M["所属市"])['公司编码'].count())
#改名
result2_b2021_C_count=result2_b2021_C_count.rename(columns={'公司编码':'公司编码_2021_国家级_count'})
result2_b2021_P_count=result2_b2021_P_count.rename(columns={'公司编码':'公司编码_2021_省级_count'})
result2_b2021_M_count=result2_b2021_M_count.rename(columns={'公司编码':'公司编码_2021_市级_count'})


##b2020
result2_b2020 = result2[result2['认定归属年度']==2020] #只取2020年
result2_b2020_C = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_C_count = pd.DataFrame(result2_b2020_C.groupby(result2_b2020_C["所属市"])['公司编码'].count())
result2_b2020_P = result2_b2020[result2_b2020['相应级别'].isin(['省级'])]
result2_b2020_P_count = pd.DataFrame(result2_b2020_P.groupby(result2_b2020_P["所属市"])['公司编码'].count())
result2_b2020_M = result2_b2020[result2_b2020['相应级别'].isin(['国家级'])]
result2_b2020_M_count = pd.DataFrame(result2_b2020_M.groupby(result2_b2020_M["所属市"])['公司编码'].count())
#改名
result2_b2020_C_count=result2_b2020_C_count.rename(columns={'公司编码':'公司编码_2020_国家级_count'})
result2_b2020_P_count=result2_b2020_P_count.rename(columns={'公司编码':'公司编码_2020_省级_count'})
result2_b2020_M_count=result2_b2020_M_count.rename(columns={'公司编码':'公司编码_2020_市级_count'})


##b2019
result2_b2019 = result2[result2['认定归属年度']==2019] #只取2019年
result2_b2019_C = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_C_count = pd.DataFrame(result2_b2019_C.groupby(result2_b2019_C["所属市"])['公司编码'].count())
result2_b2019_P = result2_b2019[result2_b2019['相应级别'].isin(['省级'])]
result2_b2019_P_count = pd.DataFrame(result2_b2019_P.groupby(result2_b2019_P["所属市"])['公司编码'].count())
result2_b2019_M = result2_b2019[result2_b2019['相应级别'].isin(['国家级'])]
result2_b2019_M_count = pd.DataFrame(result2_b2019_M.groupby(result2_b2019_M["所属市"])['公司编码'].count())
#改名
result2_b2019_C_count=result2_b2019_C_count.rename(columns={'公司编码':'公司编码_2019_国家级_count'})
result2_b2019_P_count=result2_b2019_P_count.rename(columns={'公司编码':'公司编码_2019_省级_count'})
result2_b2019_M_count=result2_b2019_M_count.rename(columns={'公司编码':'公司编码_2019_市级_count'})


##合并输出
tbs = [result2_b2021_P_count,result2_b2021_M_count,result2_b2020_C_count,result2_b2020_P_count,result2_b2020_M_count,result2_b2019_C_count,result2_b2019_P_count,result2_b2019_M_count]
result2_final = result2_b2021_C_count
for tb in tbs:
    result2_final = result2_final.merge(tb, on=['所属市'], how='outer')

result2_final.to_excel("3.技术产品-8科创资质-6制造业单项冠军_output.xlsx") #输出结果
