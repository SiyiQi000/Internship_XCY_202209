# %% [markdown]
# ## 任务2,投资 !因为无法调试各表，重复使用了变量名。需要一个表一个表run

# %% [markdown]
# #### 表'2.投融资-1新增-1A股.xlsx'

# %%
import pandas as pd
import numpy as np

#表'2.投融资-1新增-1A股.xlsx'
result=df2=pd.read_excel(r'...\1.基本信息-1基本信息（补充后）2.xlsx') 
df2=pd.read_excel(r'...\2.投融资-1新增-1A股.xlsx')  #打开表,df2
#df2
result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

result2['投资/退出日期']=pd.to_datetime(result2['投资/退出日期']) #改为时间格式
result2['成立日期']=pd.to_datetime(result2['成立日期']) #改为时间格式
#print(result2.info())

##b2022
result2_b2022 = result2[result2['投资/退出日期']<pd.datetime(2022,1,1)] #只取2022年之前
result2_b2022 = result2_b2022[result2_b2022['成立日期']<pd.datetime(2022,1,1)] #只取2022年之前

result2_b2022 = result2_b2022[~result2_b2022['注册状态'].isin(['注销','已告解散'])]
result2_b2022_sum = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['投资/退出金额（元）'].sum())
result2_b2022_count = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['投资/退出金额（元）'].count())
result2_b2022_mean = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['投资/退出金额（元）'].mean())
result2_b2022 = result2_b2022_sum.merge(result2_b2022_count,result2_b2022_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2021
result2_b2021 = result2[result2['投资/退出日期']<pd.datetime(2021,1,1)] #只取2021年之前
result2_b2021 = result2_b2021[result2_b2021['成立日期']<pd.datetime(2021,1,1)] #只取2021年之前

result2_b2021 = result2_b2021[~result2_b2021['注册状态'].isin(['注销','已告解散'])]
result2_b2021_sum = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['投资/退出金额（元）'].sum())
result2_b2021_count = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['投资/退出金额（元）'].count())
result2_b2021_mean = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['投资/退出金额（元）'].mean())
result2_b2021 = result2_b2021_sum.merge(result2_b2021_count,result2_b2021_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2020
result2_b2020 = result2[result2['投资/退出日期']<pd.datetime(2020,1,1)] #只取2020年之前
result2_b2020 = result2_b2020[result2_b2020['成立日期']<pd.datetime(2020,1,1)] #只取2020年之前

result2_b2020 = result2_b2020[~result2_b2020['注册状态'].isin(['注销','已告解散'])]
result2_b2020_sum = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['投资/退出金额（元）'].sum())
result2_b2020_count = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['投资/退出金额（元）'].count())
result2_b2020_mean = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['投资/退出金额（元）'].mean())
result2_b2020 = result2_b2020_sum.merge(result2_b2020_count,result2_b2020_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2019
result2_b2019 = result2[result2['投资/退出日期']<pd.datetime(2019,1,1)] #只取2019年之前
result2_b2019 = result2_b2019[result2_b2019['成立日期']<pd.datetime(2019,1,1)] #只取2019年之前

result2_b2019 = result2_b2019[~result2_b2019['注册状态'].isin(['注销','已告解散'])]
result2_b2019_sum = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['投资/退出金额（元）'].sum())
result2_b2019_count = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['投资/退出金额（元）'].count())
result2_b2019_mean = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['投资/退出金额（元）'].mean())
result2_b2019 = result2_b2019_sum.merge(result2_b2019_count,result2_b2019_mean,how='left',on=['所属市'])  #合并sum,count,mean

##合并年份4个表并输出
result2_final = result2_b2022.merge(result2_b2021,result2_b2020,result2_b2019,how='left',on=['所属市'])
result2_final.to_excel("2.投融资-1新增-1A股（输出）.xlsx") #输出结果

# %% [markdown]
# #### 表'2.投融资-1新增-2工商投资.xlsx'

# %%
import pandas as pd
import numpy as np

#表'2.投融资-1新增-2工商投资.xlsx'
result=df2=pd.read_excel(r'...\1.基本信息-1基本信息（补充后）2.xlsx') 
df2=pd.read_excel(r'...\2.投融资-1新增-2工商投资.xlsx')  #打开表,df2
#df2
result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

result2['XXX日期']=pd.to_datetime(result2['XXX日期']) #改为时间格式
result2['成立日期']=pd.to_datetime(result2['成立日期']) #改为时间格式
#print(result2.info())

##b2022
result2_b2022 = result2[result2['XXX日期']<pd.datetime(2022,1,1)] #只取2022年之前
result2_b2022 = result2_b2022[result2_b2022['成立日期']<pd.datetime(2022,1,1)] #只取2022年之前

result2_b2022 = result2_b2022[~result2_b2022['注册状态'].isin(['注销','已告解散'])]
result2_b2022_count = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX计数项'].count())

##b2021
result2_b2021 = result2[result2['XXX日期']<pd.datetime(2021,1,1)] #只取2021年之前
result2_b2021 = result2_b2021[result2_b2021['成立日期']<pd.datetime(2021,1,1)] #只取2021年之前

result2_b2021 = result2_b2021[~result2_b2021['注册状态'].isin(['注销','已告解散'])]
result2_b2021_count = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX计数项'].count())

##b2020
result2_b2020 = result2[result2['XXX日期']<pd.datetime(2020,1,1)] #只取2020年之前
result2_b2020 = result2_b2020[result2_b2020['成立日期']<pd.datetime(2020,1,1)] #只取2020年之前

result2_b2020 = result2_b2020[~result2_b2020['注册状态'].isin(['注销','已告解散'])]
result2_b2020_count = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX计数项'].count())

##b2019
result2_b2019 = result2[result2['XXX日期']<pd.datetime(2019,1,1)] #只取2019年之前
result2_b2019 = result2_b2019[result2_b2019['成立日期']<pd.datetime(2019,1,1)] #只取2019年之前

result2_b2019 = result2_b2019[~result2_b2019['注册状态'].isin(['注销','已告解散'])]
result2_b2019_count = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX计数项'].count())

##合并年份4个表并输出
result2_final = result2_b2022_count.merge(result2_b2021_count,result2_b2020_count,result2_b2019_count,how='left',on=['所属市'])
result2_final.to_excel("2.投融资-1新增-2工商投资（输出）.xlsx") #输出结果

# %% [markdown]
# #### 表'2.投融资-1新增-3三板.xlsx'

# %%
import pandas as pd
import numpy as np

#表'2.投融资-1新增-3三板.xlsx'
result=df2=pd.read_excel(r'...\1.基本信息-1基本信息（补充后）2.xlsx') 
df2=pd.read_excel(r'...\2.投融资-1新增-3三板.xlsx')  #打开表,df2
#df2
result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

result2['XXX日期']=pd.to_datetime(result2['XXX日期']) #改为时间格式
result2['成立日期']=pd.to_datetime(result2['成立日期']) #改为时间格式
#print(result2.info())

##b2022
result2_b2022 = result2[result2['XXX日期']<pd.datetime(2022,1,1)] #只取2022年之前
result2_b2022 = result2_b2022[result2_b2022['成立日期']<pd.datetime(2022,1,1)] #只取2022年之前

result2_b2022 = result2_b2022[~result2_b2022['注册状态'].isin(['注销','已告解散'])]
result2_b2022_sum = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX金额'].sum())
result2_b2022_count = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX金额'].count())
result2_b2022_mean = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX金额'].mean())
result2_b2022 = result2_b2022_sum.merge(result2_b2022_count,result2_b2022_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2021
result2_b2021 = result2[result2['XXX日期']<pd.datetime(2021,1,1)] #只取2021年之前
result2_b2021 = result2_b2021[result2_b2021['成立日期']<pd.datetime(2021,1,1)] #只取2021年之前

result2_b2021 = result2_b2021[~result2_b2021['注册状态'].isin(['注销','已告解散'])]
result2_b2021_sum = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX金额'].sum())
result2_b2021_count = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX金额'].count())
result2_b2021_mean = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX金额'].mean())
result2_b2021 = result2_b2021_sum.merge(result2_b2021_count,result2_b2021_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2020
result2_b2020 = result2[result2['XXX日期']<pd.datetime(2020,1,1)] #只取2020年之前
result2_b2020 = result2_b2020[result2_b2020['成立日期']<pd.datetime(2020,1,1)] #只取2020年之前

result2_b2020 = result2_b2020[~result2_b2020['注册状态'].isin(['注销','已告解散'])]
result2_b2020_sum = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX金额'].sum())
result2_b2020_count = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX金额'].count())
result2_b2020_mean = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX金额'].mean())
result2_b2020 = result2_b2020_sum.merge(result2_b2020_count,result2_b2020_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2019
result2_b2019 = result2[result2['XXX日期']<pd.datetime(2019,1,1)] #只取2019年之前
result2_b2019 = result2_b2019[result2_b2019['成立日期']<pd.datetime(2019,1,1)] #只取2019年之前

result2_b2019 = result2_b2019[~result2_b2019['注册状态'].isin(['注销','已告解散'])]
result2_b2019_sum = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX金额'].sum())
result2_b2019_count = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX金额'].count())
result2_b2019_mean = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX金额'].mean())
result2_b2019 = result2_b2019_sum.merge(result2_b2019_count,result2_b2019_mean,how='left',on=['所属市'])  #合并sum,count,mean

##合并年份4个表并输出
result2_final = result2_b2022.merge(result2_b2021,result2_b2020,result2_b2019,how='left',on=['所属市'])
result2_final.to_excel("2.投融资-1新增-3三板（输出）.xlsx") #输出结果

# %% [markdown]
# #### 表'2.投融资-2拟上市.xlsx'

# %%
import pandas as pd
import numpy as np

#表'2.投融资-2拟上市.xlsx'
result=df2=pd.read_excel(r'...\1.基本信息-1基本信息（补充后）2.xlsx') 
df2=pd.read_excel(r'...\2.投融资-2拟上市.xlsx')  #打开表,df2
#df2
result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

result2['XXX日期']=pd.to_datetime(result2['XXX日期']) #改为时间格式
result2['成立日期']=pd.to_datetime(result2['成立日期']) #改为时间格式
#print(result2.info())

##b2022
result2_b2022 = result2[result2['XXX日期']<pd.datetime(2022,1,1)] #只取2022年之前
result2_b2022 = result2_b2022[result2_b2022['成立日期']<pd.datetime(2022,1,1)] #只取2022年之前

result2_b2022 = result2_b2022[~result2_b2022['注册状态'].isin(['注销','已告解散'])]
result2_b2022_count = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX计数项'].count())

##b2021
result2_b2021 = result2[result2['XXX日期']<pd.datetime(2021,1,1)] #只取2021年之前
result2_b2021 = result2_b2021[result2_b2021['成立日期']<pd.datetime(2021,1,1)] #只取2021年之前

result2_b2021 = result2_b2021[~result2_b2021['注册状态'].isin(['注销','已告解散'])]
result2_b2021_count = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX计数项'].count())

##b2020
result2_b2020 = result2[result2['XXX日期']<pd.datetime(2020,1,1)] #只取2020年之前
result2_b2020 = result2_b2020[result2_b2020['成立日期']<pd.datetime(2020,1,1)] #只取2020年之前

result2_b2020 = result2_b2020[~result2_b2020['注册状态'].isin(['注销','已告解散'])]
result2_b2020_count = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX计数项'].count())

##b2019
result2_b2019 = result2[result2['XXX日期']<pd.datetime(2019,1,1)] #只取2019年之前
result2_b2019 = result2_b2019[result2_b2019['成立日期']<pd.datetime(2019,1,1)] #只取2019年之前

result2_b2019 = result2_b2019[~result2_b2019['注册状态'].isin(['注销','已告解散'])]
result2_b2019_count = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX计数项'].count())

##合并年份4个表并输出
result2_final = result2_b2022_count.merge(result2_b2021_count,result2_b2020_count,result2_b2019_count,how='left',on=['所属市'])
result2_final.to_excel("2.投融资-2拟上市（输出）.xlsx") #输出结果

# %% [markdown]
# #### 表'2.投融资-3定增-1A股.xlsx'

# %%
import pandas as pd
import numpy as np

#表'2.投融资-3定增-1A股.xlsx'
result=df2=pd.read_excel(r'...\1.基本信息-1基本信息（补充后）2.xlsx') 
df2=pd.read_excel(r'...\2.投融资-3定增-1A股.xlsx')  #打开表,df2
#df2
result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

result2['XXX日期']=pd.to_datetime(result2['XXX日期']) #改为时间格式
result2['成立日期']=pd.to_datetime(result2['成立日期']) #改为时间格式
#print(result2.info())

##b2022
result2_b2022 = result2[result2['XXX日期']<pd.datetime(2022,1,1)] #只取2022年之前
result2_b2022 = result2_b2022[result2_b2022['成立日期']<pd.datetime(2022,1,1)] #只取2022年之前

result2_b2022 = result2_b2022[~result2_b2022['注册状态'].isin(['注销','已告解散'])]
result2_b2022_sum = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX金额'].sum())
result2_b2022_count = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX金额'].count())
result2_b2022_mean = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX金额'].mean())
result2_b2022 = result2_b2022_sum.merge(result2_b2022_count,result2_b2022_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2021
result2_b2021 = result2[result2['XXX日期']<pd.datetime(2021,1,1)] #只取2021年之前
result2_b2021 = result2_b2021[result2_b2021['成立日期']<pd.datetime(2021,1,1)] #只取2021年之前

result2_b2021 = result2_b2021[~result2_b2021['注册状态'].isin(['注销','已告解散'])]
result2_b2021_sum = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX金额'].sum())
result2_b2021_count = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX金额'].count())
result2_b2021_mean = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX金额'].mean())
result2_b2021 = result2_b2021_sum.merge(result2_b2021_count,result2_b2021_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2020
result2_b2020 = result2[result2['XXX日期']<pd.datetime(2020,1,1)] #只取2020年之前
result2_b2020 = result2_b2020[result2_b2020['成立日期']<pd.datetime(2020,1,1)] #只取2020年之前

result2_b2020 = result2_b2020[~result2_b2020['注册状态'].isin(['注销','已告解散'])]
result2_b2020_sum = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX金额'].sum())
result2_b2020_count = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX金额'].count())
result2_b2020_mean = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX金额'].mean())
result2_b2020 = result2_b2020_sum.merge(result2_b2020_count,result2_b2020_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2019
result2_b2019 = result2[result2['XXX日期']<pd.datetime(2019,1,1)] #只取2019年之前
result2_b2019 = result2_b2019[result2_b2019['成立日期']<pd.datetime(2019,1,1)] #只取2019年之前

result2_b2019 = result2_b2019[~result2_b2019['注册状态'].isin(['注销','已告解散'])]
result2_b2019_sum = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX金额'].sum())
result2_b2019_count = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX金额'].count())
result2_b2019_mean = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX金额'].mean())
result2_b2019 = result2_b2019_sum.merge(result2_b2019_count,result2_b2019_mean,how='left',on=['所属市'])  #合并sum,count,mean

##合并年份4个表并输出
result2_final = result2_b2022.merge(result2_b2021,result2_b2020,result2_b2019,how='left',on=['所属市'])
result2_final.to_excel("2.投融资-3定增-1A股（输出）.xlsx") #输出结果

# %% [markdown]
# #### 表'2.投融资-3定增-2三板.xlsx'

# %%
import pandas as pd
import numpy as np

#表'2.投融资-3定增-2三板.xlsx'
result=df2=pd.read_excel(r'...\1.基本信息-1基本信息（补充后）2.xlsx') 
df2=pd.read_excel(r'...\2.投融资-3定增-2三板.xlsx')  #打开表,df2
#df2
result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

result2['XXX日期']=pd.to_datetime(result2['XXX日期']) #改为时间格式
result2['成立日期']=pd.to_datetime(result2['成立日期']) #改为时间格式
#print(result2.info())

##b2022
result2_b2022 = result2[result2['XXX日期']<pd.datetime(2022,1,1)] #只取2022年之前
result2_b2022 = result2_b2022[result2_b2022['成立日期']<pd.datetime(2022,1,1)] #只取2022年之前

result2_b2022 = result2_b2022[~result2_b2022['注册状态'].isin(['注销','已告解散'])]
result2_b2022_sum = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX金额'].sum())
result2_b2022_count = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX金额'].count())
result2_b2022_mean = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX金额'].mean())
result2_b2022 = result2_b2022_sum.merge(result2_b2022_count,result2_b2022_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2021
result2_b2021 = result2[result2['XXX日期']<pd.datetime(2021,1,1)] #只取2021年之前
result2_b2021 = result2_b2021[result2_b2021['成立日期']<pd.datetime(2021,1,1)] #只取2021年之前

result2_b2021 = result2_b2021[~result2_b2021['注册状态'].isin(['注销','已告解散'])]
result2_b2021_sum = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX金额'].sum())
result2_b2021_count = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX金额'].count())
result2_b2021_mean = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX金额'].mean())
result2_b2021 = result2_b2021_sum.merge(result2_b2021_count,result2_b2021_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2020
result2_b2020 = result2[result2['XXX日期']<pd.datetime(2020,1,1)] #只取2020年之前
result2_b2020 = result2_b2020[result2_b2020['成立日期']<pd.datetime(2020,1,1)] #只取2020年之前

result2_b2020 = result2_b2020[~result2_b2020['注册状态'].isin(['注销','已告解散'])]
result2_b2020_sum = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX金额'].sum())
result2_b2020_count = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX金额'].count())
result2_b2020_mean = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX金额'].mean())
result2_b2020 = result2_b2020_sum.merge(result2_b2020_count,result2_b2020_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2019
result2_b2019 = result2[result2['XXX日期']<pd.datetime(2019,1,1)] #只取2019年之前
result2_b2019 = result2_b2019[result2_b2019['成立日期']<pd.datetime(2019,1,1)] #只取2019年之前

result2_b2019 = result2_b2019[~result2_b2019['注册状态'].isin(['注销','已告解散'])]
result2_b2019_sum = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX金额'].sum())
result2_b2019_count = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX金额'].count())
result2_b2019_mean = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX金额'].mean())
result2_b2019 = result2_b2019_sum.merge(result2_b2019_count,result2_b2019_mean,how='left',on=['所属市'])  #合并sum,count,mean

##合并年份4个表并输出
result2_final = result2_b2022.merge(result2_b2021,result2_b2020,result2_b2019,how='left',on=['所属市'])
result2_final.to_excel("2.投融资-3定增-2三板（输出）.xlsx") #输出结果

# %% [markdown]
# #### 表'2.投融资-4并购.xlsx'

# %%
import pandas as pd
import numpy as np

#表'2.投融资-4并购.xlsx'
result=df2=pd.read_excel(r'...\1.基本信息-1基本信息（补充后）2.xlsx') 
df2=pd.read_excel(r'...\2.投融资-4并购.xlsx')  #打开表,df2
#df2
result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

result2['XXX日期']=pd.to_datetime(result2['XXX日期']) #改为时间格式
result2['成立日期']=pd.to_datetime(result2['成立日期']) #改为时间格式
#print(result2.info())

##b2022
result2_b2022 = result2[result2['XXX日期']<pd.datetime(2022,1,1)] #只取2022年之前
result2_b2022 = result2_b2022[result2_b2022['成立日期']<pd.datetime(2022,1,1)] #只取2022年之前

result2_b2022 = result2_b2022[~result2_b2022['注册状态'].isin(['注销','已告解散'])]
result2_b2022_sum = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX金额'].sum())
result2_b2022_count = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX金额'].count())
result2_b2022_mean = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX金额'].mean())
result2_b2022 = result2_b2022_sum.merge(result2_b2022_count,result2_b2022_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2021
result2_b2021 = result2[result2['XXX日期']<pd.datetime(2021,1,1)] #只取2021年之前
result2_b2021 = result2_b2021[result2_b2021['成立日期']<pd.datetime(2021,1,1)] #只取2021年之前

result2_b2021 = result2_b2021[~result2_b2021['注册状态'].isin(['注销','已告解散'])]
result2_b2021_sum = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX金额'].sum())
result2_b2021_count = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX金额'].count())
result2_b2021_mean = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX金额'].mean())
result2_b2021 = result2_b2021_sum.merge(result2_b2021_count,result2_b2021_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2020
result2_b2020 = result2[result2['XXX日期']<pd.datetime(2020,1,1)] #只取2020年之前
result2_b2020 = result2_b2020[result2_b2020['成立日期']<pd.datetime(2020,1,1)] #只取2020年之前

result2_b2020 = result2_b2020[~result2_b2020['注册状态'].isin(['注销','已告解散'])]
result2_b2020_sum = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX金额'].sum())
result2_b2020_count = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX金额'].count())
result2_b2020_mean = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX金额'].mean())
result2_b2020 = result2_b2020_sum.merge(result2_b2020_count,result2_b2020_mean,how='left',on=['所属市'])  #合并sum,count,mean

##b2019
result2_b2019 = result2[result2['XXX日期']<pd.datetime(2019,1,1)] #只取2019年之前
result2_b2019 = result2_b2019[result2_b2019['成立日期']<pd.datetime(2019,1,1)] #只取2019年之前

result2_b2019 = result2_b2019[~result2_b2019['注册状态'].isin(['注销','已告解散'])]
result2_b2019_sum = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX金额'].sum())
result2_b2019_count = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX金额'].count())
result2_b2019_mean = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX金额'].mean())
result2_b2019 = result2_b2019_sum.merge(result2_b2019_count,result2_b2019_mean,how='left',on=['所属市'])  #合并sum,count,mean

##合并年份4个表并输出
result2_final = result2_b2022.merge(result2_b2021,result2_b2020,result2_b2019,how='left',on=['所属市'])
result2_final.to_excel("2.投融资-4并购（输出）.xlsx") #输出结果

# %% [markdown]
# #### 表'2.投融资-5私募.xlsx'

# %%
import pandas as pd
import numpy as np

#表'2.投融资-5私募.xlsx'
result=df2=pd.read_excel(r'...\1.基本信息-1基本信息（补充后）2.xlsx') 
df2=pd.read_excel(r'...\2.投融资-5私募.xlsx')  #打开表,df2
#df2
result2 = result.merge(df2,how='left',on=['公司编码'])  #将两个表合并到左表result,on'公司编码',result2
#result

result2['XXX日期']=pd.to_datetime(result2['XXX日期']) #改为时间格式
result2['成立日期']=pd.to_datetime(result2['成立日期']) #改为时间格式
#print(result2.info())

##b2022
result2_b2022 = result2[result2['XXX日期']<pd.datetime(2022,1,1)] #只取2022年之前
result2_b2022 = result2_b2022[result2_b2022['成立日期']<pd.datetime(2022,1,1)] #只取2022年之前

result2_b2022 = result2_b2022[~result2_b2022['注册状态'].isin(['注销','已告解散'])]
result2_b2022_count = pd.DataFrame(result2_b2022.groupby(result2_b2022["所属市"])['XXX计数项'].count())

##b2021
result2_b2021 = result2[result2['XXX日期']<pd.datetime(2021,1,1)] #只取2021年之前
result2_b2021 = result2_b2021[result2_b2021['成立日期']<pd.datetime(2021,1,1)] #只取2021年之前

result2_b2021 = result2_b2021[~result2_b2021['注册状态'].isin(['注销','已告解散'])]
result2_b2021_count = pd.DataFrame(result2_b2021.groupby(result2_b2021["所属市"])['XXX计数项'].count())

##b2020
result2_b2020 = result2[result2['XXX日期']<pd.datetime(2020,1,1)] #只取2020年之前
result2_b2020 = result2_b2020[result2_b2020['成立日期']<pd.datetime(2020,1,1)] #只取2020年之前

result2_b2020 = result2_b2020[~result2_b2020['注册状态'].isin(['注销','已告解散'])]
result2_b2020_count = pd.DataFrame(result2_b2020.groupby(result2_b2020["所属市"])['XXX计数项'].count())

##b2019
result2_b2019 = result2[result2['XXX日期']<pd.datetime(2019,1,1)] #只取2019年之前
result2_b2019 = result2_b2019[result2_b2019['成立日期']<pd.datetime(2019,1,1)] #只取2019年之前

result2_b2019 = result2_b2019[~result2_b2019['注册状态'].isin(['注销','已告解散'])]
result2_b2019_count = pd.DataFrame(result2_b2019.groupby(result2_b2019["所属市"])['XXX计数项'].count())

##合并年份4个表并输出
result2_final = result2_b2022_count.merge(result2_b2021_count,result2_b2020_count,result2_b2019_count,how='left',on=['所属市'])
result2_final.to_excel("2.投融资-5私募（输出）.xlsx") #输出结果
