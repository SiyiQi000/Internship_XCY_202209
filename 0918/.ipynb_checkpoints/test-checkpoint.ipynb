# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_excel(r'D:\my github\Internship_XCY_202209\0918\Hospital_test.xlsx')
df1
# Out:
#     城市名称  城市规模    经济水平 地理分区（4） 地理分区（7）   老龄化率  Unnamed: 6       合并1  \
# 0    安庆市  中等城市   欠发达城市      中部      华东  17.06         NaN   15530.0
# 1    蚌埠市  中等城市   欠发达城市      中部      华东  14.40         NaN       NaN
# 2    亳州市   小城市   欠发达城市      中部      华东  13.61         NaN       NaN
# 3    池州市   小城市   欠发达城市      中部      华东  16.74         NaN       NaN
# 4    滁州市   小城市  中等发达城市      中部      华东  15.97         NaN       NaN
# ..   ...   ...     ...     ...     ...    ...         ...       ...
# 291  绍兴市  中等城市  中等发达城市      东部      华东  16.21         NaN   21242.0
# 292  台州市   大城市  中等发达城市      东部      华东  13.80         NaN   24955.0
# 293  温州市   大城市  中等发达城市      东部      华东  11.71         NaN   36327.0
# 294  舟山市  中等城市  中等发达城市      东部      华东  17.09         NaN    5056.0
# 295  重庆市  超大城市  中等发达城市      西部      西南  16.30         NaN  150500.0
#
#      2018医院床位数       合并2  ...  Unnamed: 11  2017常住人口  2018常住人口  2019常住人口  \
# 0      16773.0   17915.0  ...          NaN     464.3    469.10    470.80
# ...

# %%
df2=pd.read_excel(r'D:\my github\Internship_XCY_202209\0918\Hospital_test_2.xlsx')
df2
# Out:
#     城市名称      合并1      合并2
# 0    安庆市      NaN      NaN
# 1    蚌埠市  15289.0      NaN
# 2    亳州市  12545.0  16448.0
# 3    池州市   5188.0   6550.0
# 4    滁州市  13721.0  16437.0
# ..   ...      ...      ...
# 291  绍兴市      NaN      NaN
# 292  台州市      NaN      NaN
# 293  温州市      NaN      NaN
# 294  舟山市      NaN      NaN
# 295  重庆市      NaN      NaN
#
# [296 rows x 3 columns]

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left: 'DataFrame | Series', right: 'DataFrame | Series', how: 'str' = 'inner', on: 'IndexLabel | None' = None, left_on: 'IndexLabel | None' = None, right_on: 'IndexLabel | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool' = True, indicator: 'bool' = False, validate: 'str | None' = None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     A named Series object is treated as a DataFrame with a single named column.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#     When performing a cross merge, no column specifications to merge on are
#     allowed.
#
#     Parameters
#     ----------
# ...

# %%
result = df1.merge(df2,how='outer',on=['城市名称'])
result
# Out:
#     城市名称  城市规模    经济水平 地理分区（4） 地理分区（7）   老龄化率  Unnamed: 6     合并1_x  \
# 0    安庆市  中等城市   欠发达城市      中部      华东  17.06         NaN   15530.0
# 1    蚌埠市  中等城市   欠发达城市      中部      华东  14.40         NaN       NaN
# 2    亳州市   小城市   欠发达城市      中部      华东  13.61         NaN       NaN
# 3    池州市   小城市   欠发达城市      中部      华东  16.74         NaN       NaN
# 4    滁州市   小城市  中等发达城市      中部      华东  15.97         NaN       NaN
# ..   ...   ...     ...     ...     ...    ...         ...       ...
# 291  绍兴市  中等城市  中等发达城市      东部      华东  16.21         NaN   21242.0
# 292  台州市   大城市  中等发达城市      东部      华东  13.80         NaN   24955.0
# 293  温州市   大城市  中等发达城市      东部      华东  11.71         NaN   36327.0
# 294  舟山市  中等城市  中等发达城市      东部      华东  17.09         NaN    5056.0
# 295  重庆市  超大城市  中等发达城市      西部      西南  16.30         NaN  150500.0
#
#      2018医院床位数     合并2_x  ...  2018常住人口  2019常住人口   2020常住人口  Unnamed: 16  \
# 0      16773.0   17915.0  ...    469.10    470.80   416.5284          NaN
# ...

# %%
result.loc[result['合并1_x'].isna(),'合并1_x']=result[result['合并1_x'].isna()]['合并1_y']
result
# Out:
#     城市名称  城市规模    经济水平 地理分区（4） 地理分区（7）   老龄化率  Unnamed: 6     合并1_x  \
# 0    安庆市  中等城市   欠发达城市      中部      华东  17.06         NaN   15530.0
# 1    蚌埠市  中等城市   欠发达城市      中部      华东  14.40         NaN   15289.0
# 2    亳州市   小城市   欠发达城市      中部      华东  13.61         NaN   12545.0
# 3    池州市   小城市   欠发达城市      中部      华东  16.74         NaN    5188.0
# 4    滁州市   小城市  中等发达城市      中部      华东  15.97         NaN   13721.0
# ..   ...   ...     ...     ...     ...    ...         ...       ...
# 291  绍兴市  中等城市  中等发达城市      东部      华东  16.21         NaN   21242.0
# 292  台州市   大城市  中等发达城市      东部      华东  13.80         NaN   24955.0
# 293  温州市   大城市  中等发达城市      东部      华东  11.71         NaN   36327.0
# 294  舟山市  中等城市  中等发达城市      东部      华东  17.09         NaN    5056.0
# 295  重庆市  超大城市  中等发达城市      西部      西南  16.30         NaN  150500.0
#
#      2018医院床位数     合并2_x  ...  2018常住人口  2019常住人口   2020常住人口  Unnamed: 16  \
# 0      16773.0   17915.0  ...    469.10    470.80   416.5284          NaN
# ...
