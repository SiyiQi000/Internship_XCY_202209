# %%
import pandas as pd
import numpy as np
import jenkspy

# %%
pd_reader = pd.read_csv("./Hospital_1.csv")
df = pd.DataFrame(pd_reader)
df
# Out:
#     城市名称  城市规模    经济水平 地理分区（4） 地理分区（7）   老龄化率  Unnamed: 6  2017医院床位数  \
# 0    安庆市  中等城市   欠发达城市      中部      华东  17.06         NaN      15530
# 1    蚌埠市  中等城市   欠发达城市      中部      华东  14.40         NaN      15289
# 2    亳州市   小城市   欠发达城市      中部      华东  13.61         NaN      12545
# 3    池州市   小城市   欠发达城市      中部      华东  16.74         NaN       5188
# 4    滁州市   小城市  中等发达城市      中部      华东  15.97         NaN      13721
# ..   ...   ...     ...     ...     ...    ...         ...        ...
# 290  绍兴市  中等城市  中等发达城市      东部      华东  16.21         NaN      21242
# 291  台州市   大城市  中等发达城市      东部      华东  13.80         NaN      24955
# 292  温州市   大城市  中等发达城市      东部      华东  11.71         NaN      36327
# 293  舟山市  中等城市  中等发达城市      东部      华东  17.09         NaN       5056
# 294  重庆市  超大城市  中等发达城市      西部      西南  16.30         NaN     150500
#
#      2018医院床位数  2019医院床位数  ...  Unnamed: 11  2017常住人口  2018常住人口  2019常住人口  \
# 0        16773      17915  ...          NaN     464.3    469.10    470.80
# 1        17101      18086  ...          NaN     337.7    339.20    340.17
# 2        14250      16448  ...          NaN     516.9    523.70    525.00
# 3         5913       6550  ...          NaN     144.9    147.40    148.00
# 4        14419      16437  ...          NaN     407.6    411.40    413.04
# ..         ...        ...  ...          ...       ...       ...       ...
# 290      21651      22001  ...          NaN     501.0    503.50    504.62
# 291      26879      27762  ...          NaN     611.8    613.90    614.45
# 292      37414      38313  ...          NaN     921.5    925.00    927.48
# 293       5698       5632  ...          NaN     116.8    117.30    117.48
# 294     162147     171576  ...          NaN    3144.0   3101.79   3113.10
#
#       2020常住人口  Unnamed: 16  2017每千人医院床位数  2018每千人医院床位数  2019每千人医院床位数  \
# 0     416.5284          NaN      3.344820          3.58          3.81
# 1     329.6408          NaN      4.527391          5.04          5.32
# 2     499.6844          NaN      2.426968          2.72          3.13
# 3     134.2764          NaN      3.580400          4.01          4.43
# 4     398.7054          NaN      3.366290          3.50          3.98
# ..         ...          ...           ...           ...           ...
# 290   527.0977          NaN      4.239920          4.30          4.36
# 291   662.2888          NaN      4.078947          4.38          4.52
# 292   957.2903          NaN      3.942160          4.04          4.13
# 293   115.7817          NaN      4.328767          4.86          4.79
# 294  3212.4300          NaN      4.786896          5.23          5.51
#
#      2020每千人医院床位数
# 0            5.21
# 1            6.51
# 2            3.93
# 3            5.51
# 4            4.95
# ..            ...
# 290          4.57
# 291          4.27
# 292          4.04
# 293          5.21
# 294          5.45
#
# [295 rows x 21 columns]

# %%
#Question1:全国来看（全国均值），医院总床位数和人均医院床位数的变化情况：包括数量和增长率

# %%
mean_sum_ = []
prepare_mean_sum = locals()

for i in range(0,4):
    mean_sum_ = 'mean_sum_'+ str(2017 + i)  #变量命名
    prepare_mean_sum[mean_sum_] = df.iloc[:,i+7]  #赋值
    print(mean_sum_+': '+"%.0f" %np.mean(prepare_mean_sum[mean_sum_]))  #求均值
#增长率计算见excel表“医院床位数_制图”
# Out:
# mean_sum_2017: 19870
# mean_sum_2018: 21069
# mean_sum_2019: 22153
# mean_sum_2020: 23098

# %%
mean_pers_ = []
prepare_mean_pers = locals()

for j in range(0,4):
    mean_pers_ = 'mean_pers_'+ str(2017 + j)  #变量命名
    prepare_mean_pers[mean_pers_] = df.iloc[:,j+17]  #赋值
    print(mean_pers_+': '+"%.2f" %np.mean(prepare_mean_pers[mean_pers_]))  #求均值
#增长率计算见excel表“医院床位数_制图”
# Out:
# mean_pers_2017: 4.45
# mean_pers_2018: 4.67
# mean_pers_2019: 4.90
# mean_pers_2020: 5.18

# %%
#Question2:分4大地理区和7大地理区来看的 人均医院床位数的差异（方差）

# %%
for k in range(0,4):
    a = df.groupby(df["地理分区（4）"])[str(2017+k)+'每千人医院床位数'].var()
print(a)
# Out:
# 地理分区（4）
# 东北    1.350409
# 东部    0.952388
# 中部    1.308566
# 西部    2.425848
# Name: 2017每千人医院床位数, dtype: float64
# 地理分区（4）
# 东北    1.264273
# 东部    0.997000
# 中部    1.453234
# 西部    1.963238
# Name: 2018每千人医院床位数, dtype: float64
# 地理分区（4）
# 东北    1.116148
# 东部    1.139959
# 中部    1.264812
# 西部    2.011720
# Name: 2019每千人医院床位数, dtype: float64
# 地理分区（4）
# 东北    1.078848
# 东部    0.871048
# 中部    0.809500
# 西部    1.528815
# Name: 2020每千人医院床位数, dtype: float64

# %%
for l in range(0,4):
    print(df.groupby(df["地理分区（7）"])[str(2017+l)+'每千人医院床位数'].var())
# Out:
# 地理分区（7）
# 东北    1.350409
# 华东    0.852797
# 华中    1.302391
# 华北    1.224735
# 华南    0.738122
# 西北    2.648421
# 西南    1.807051
# Name: 2017每千人医院床位数, dtype: float64
# 地理分区（7）
# 东北    1.264273
# 华东    0.860851
# 华中    1.463763
# 华北    1.185739
# 华南    1.002858
# 西北    1.482987
# 西南    2.138289
# Name: 2018每千人医院床位数, dtype: float64
# 地理分区（7）
# 东北    1.116148
# 华东    0.883308
# 华中    1.261619
# 华北    1.152762
# 华南    1.301439
# 西北    1.737301
# 西南    1.918220
# Name: 2019每千人医院床位数, dtype: float64
# 地理分区（7）
# 东北    1.078848
# 华东    0.713331
# 华中    0.741801
# 华北    0.810481
# 华南    0.648948
# 西北    1.274129
# 西南    1.402541
# Name: 2020每千人医院床位数, dtype: float64

# %%
#Question3:不同组的老龄化率下（自然断点法，高中低三类老龄化率），总的医院床位数 和 人均医院床位数的差异情况（方差）

# %%
aging_rate_divide = df["老龄化率"]

# %%
breaks = jenkspy.jenks_breaks(aging_rate_divide,n_classes = 6)
print(breaks)
#其余步骤见excel表“医院床位数_制图”
# Out:
# [3.22, 7.82, 11.17, 13.2, 15.37, 18.22, 22.67]

# %%
#Question4:不同城市规模、经济水平下的人均医院床位数差异

# %%
for m in range(0,4):
    print(df.groupby(df["城市规模"])[str(2017+m)+'每千人医院床位数'].var())
# Out:
# 城市规模
# 中等城市    1.036018
# 大城市     2.282846
# 小城市     1.335374
# 特大城市    1.007325
# 超大城市    0.674120
# Name: 2017每千人医院床位数, dtype: float64
# 城市规模
# 中等城市    1.219085
# 大城市     1.839952
# 小城市     1.260079
# 特大城市    1.197270
# 超大城市    0.917670
# Name: 2018每千人医院床位数, dtype: float64
# 城市规模
# 中等城市    1.053161
# 大城市     1.840289
# 小城市     1.457546
# 特大城市    0.443970
# 超大城市    1.007380
# Name: 2019每千人医院床位数, dtype: float64
# 城市规模
# 中等城市    1.217503
# 大城市     1.516018
# 小城市     1.453791
# 特大城市    0.406470
# 超大城市    1.045370
# Name: 2020每千人医院床位数, dtype: float64

# %%
for n in range(0,4):
    print(df.groupby(df["经济水平"])[str(2017+n)+'每千人医院床位数'].var())
# Out:
# 经济水平
# 中等发达城市    2.328792
# 发达城市      1.700858
# 欠发达城市     1.200622
# Name: 2017每千人医院床位数, dtype: float64
# 经济水平
# 中等发达城市    1.854533
# 发达城市      1.713950
# 欠发达城市     1.276404
# Name: 2018每千人医院床位数, dtype: float64
# 经济水平
# 中等发达城市    1.645667
# 发达城市      1.622787
# 欠发达城市     1.399760
# Name: 2019每千人医院床位数, dtype: float64
# 经济水平
# 中等发达城市    1.238562
# 发达城市      1.321820
# 欠发达城市     1.503346
# Name: 2020每千人医院床位数, dtype: float64
